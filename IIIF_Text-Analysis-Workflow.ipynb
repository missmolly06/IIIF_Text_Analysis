# %% [markdown]
# # IIIF Workflow: Preparing for Text Analysis
#
# #### For this tutorial, make sure you are using Python [conda env:base] as your kernel
#
# This notebook will show you how to prepare files in order to do text analysis on digitized archival materials available in UCLA Library Digital Collections. The workflow provides a good introduction to using python in the command line.
#
# **Steps used in this workflow:**
#
# 1. Download JPEG images from IIIF-based digital libraries (BASH & PYTHON)
# 2. Convert JPEGs to PDFs (PYTHON)
# 3. Render PDFs as text-searchable (OCR the PDFs) (BASH)
# 4. Convert PDFs to .txt files (BASH)

# %% [markdown]
# ## Step 1: Download JPEG images from IIIF-based digital libraries (BASH & PYTHON)
# This section is based on ChatGPT assisted code in response to failed attempts to use python package iiif-download (https://pypi.org/project/iiif-download/) and iiif-downloader (https://github.com/YaleDHLab/iiif-downloader, https://github.com/ClaudioMartino/IIIF-Downloader). I may do furhter research to see if UCLA intentially blocks IIIF donwloaders, thus requiring this more complicated coding.

# %%
#Bash
#confirm the parent directory where your files will be downloaded
# !pwd
# Out:
# /Users/mhaigh/Downloads

# %%
#Python
#create the sub-directory for your project
import os

# Define the folder path
folder_path = "iiif-studentactivism"

# Create the folder
os.makedirs(folder_path, exist_ok=True)  # exist_ok=True avoids error if folder exists

print(f"Folder '{folder_path}' created successfully!")
# Out:
# Folder 'iiif-studentactivism' created successfully!

# %%
#Bash
#install the library that will allow you to use the IIIF manifest code to download all JPEGs associated with the digital object described in the manifest
# !pip install iiif-download
# Out:
# Requirement already satisfied: iiif-download in /opt/anaconda3/lib/python3.13/site-packages (0.1.15)
# Requirement already satisfied: Pillow>=11.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from iiif-download) (12.0.0)
# Requirement already satisfied: requests>=2.32.0 in /opt/anaconda3/lib/python3.13/site-packages (from iiif-download) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.0 in /opt/anaconda3/lib/python3.13/site-packages (from iiif-download) (4.67.1)
# Requirement already satisfied: urllib3>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from iiif-download) (2.5.0)
# Requirement already satisfied: aiohttp>=3.10 in /opt/anaconda3/lib/python3.13/site-packages (from iiif-download) (3.13.2)
# Requirement already satisfied: aiofiles>=24.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from iiif-download) (25.1.0)
# Requirement already satisfied: rich>=13.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from iiif-download) (14.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.10->iiif-download) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.10->iiif-download) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.10->iiif-download) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.10->iiif-download) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.10->iiif-download) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.10->iiif-download) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp>=3.10->iiif-download) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10->iiif-download) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.0->iiif-download) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.0->iiif-download) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.9.0->iiif-download) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.9.0->iiif-download) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.0->iiif-download) (0.1.2)

# %%
#Python
#Download images from the first manifest
import os
import requests
from urllib.parse import urlparse

# === CONFIG ===
manifest_url = "https://iiif.library.ucla.edu/ark%3A%2F21198%2Fz1xq34bs/manifest"

# Create a folder name based on manifest URL (safe folder name)
parsed_url = urlparse(manifest_url)
folder_name = os.path.splitext(os.path.basename(parsed_url.path))[0]
output_dir = os.path.join("iiif-studentactivism", folder_name)
os.makedirs(output_dir, exist_ok=True)

# Step 1: Download manifest JSON
resp = requests.get(manifest_url)
resp.raise_for_status()
manifest = resp.json()

# Step 2: Loop through canvases
canvases = manifest.get("items", [])
print(f"Found {len(canvases)} canvases.")

image_counter = 1
for canvas in canvases:
    items = canvas.get("items", [])
    
    for item in items:
        for body in item.get("items", []):
            image_info = body.get("body", body)
            service = image_info.get("service")
            
            # If service is a list, take the first
            if isinstance(service, list):
                service = service[0]
            
            if service:
                iiif_id = service.get("@id") or service.get("id")
                if iiif_id:
                    # Full-resolution IIIF URL
                    image_url = f"{iiif_id}/full/full/0/default.jpg"
                    
                    # Generic filename
                    filename = f"image_{image_counter}.jpg"
                    image_path = os.path.join(output_dir, filename)
                    
                    # Download image
                    r = requests.get(image_url)
                    if r.status_code == 200:
                        with open(image_path, "wb") as f:
                            f.write(r.content)
                        print(f"Downloaded {filename}")
                        image_counter += 1
                    else:
                        print(f"Failed to download image {image_counter}, status: {r.status_code}")
# Out:
# Found 29 canvases.
# Downloaded image_1.jpg
# Downloaded image_2.jpg
# Downloaded image_3.jpg
# Downloaded image_4.jpg
# Downloaded image_5.jpg
# Downloaded image_6.jpg
# Downloaded image_7.jpg
# Downloaded image_8.jpg
# Downloaded image_9.jpg
# Downloaded image_10.jpg
# Downloaded image_11.jpg
# Downloaded image_12.jpg
# Downloaded image_13.jpg
# Downloaded image_14.jpg
# Downloaded image_15.jpg
# Downloaded image_16.jpg
# Downloaded image_17.jpg
# Downloaded image_18.jpg
# Downloaded image_19.jpg
# Downloaded image_20.jpg
# Downloaded image_21.jpg
# Downloaded image_22.jpg
# Downloaded image_23.jpg
# Downloaded image_24.jpg
# Downloaded image_25.jpg
# Downloaded image_26.jpg
# Downloaded image_27.jpg
# Downloaded image_28.jpg
# Downloaded image_29.jpg

# %% [markdown]
# ## Step 2: Convert JPEGs to PDFs: Python
# Code source: https://stackoverflow.com/questions/27327513/create-pdf-from-a-list-of-images
#
# Note: for small amounts of files, right-clicking and choosing "convert to PDF" may suffice; for large amounts of files (or if wanting to practice python skills), follow these steps!

# %%
# Source - https://stackoverflow.com/a
# Posted by ilovecomputer, modified by community. See post 'Timeline' for change history
# Retrieved 2025-12-03, License - CC BY-SA 4.0

from PIL import Image  
# install by > python3 -m pip install --upgrade Pillow  # ref. https://pillow.readthedocs.io/en/latest/installation.html#basic-installation

#replace the word "path" below with the directory where your files downloaded
images = [
    Image.open("/Users/mhaigh/Downloads/iiif-studentactivism/manifest/" + f)
    for f in ["image_1.jpg", "image_2.jpg", "image_3.jpg", "image_4.jpg", 
              "image_5.jpg", "image_6.jpg", "image_7.jpg", "image_8.jpg", 
              "image_9.jpg", "image_10.jpg", "image_11.jpg", "image_12.jpg", 
              "image_13.jpg", "image_14.jpg", "image_15.jpg", "image_16.jpg",
              "image_17.jpg", "image_18.jpg", "image_19.jpg", "image_20.jpg", 
              "image_21.jpg", "image_22.jpg", "image_23.jpg", "image_24.jpg", 
              "image_25.jpg", "image_26.jpg", "image_27.jpg", "image_28.jpg", 
              "image_29.jpg"
]
] 

pdf_path = "/Users/mhaigh/Downloads/iiif-studentactivism/manifest/manifest.pdf"
    
images[0].save(
    pdf_path, "PDF" ,resolution=100.0, save_all=True, append_images=images[1:]
)

# %% [markdown]
# ## Step 3: Render PDFs as text-searchable (OCR the PDFs): Bash
# This section is based on the Programming Historian tutorial: https://programminghistorian.org/en/lessons/working-with-batches-of-pdf-files

# %%
#Steps 3 and 4 require you run some code OUTSIDE of this notebook, in your command line.  

#Copy-paste the following and follow all instructions from your command line:
#/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"

#Then, copy-paste the following in your command line
#brew install poppler pkg-config

#Then, copy-paste the following in your command line
#brew install unpaper

#Then, copy-paste the following in your command line
#brew install ghostscript

#then you are ready to return to this notebook and install pdftotext!

# %%
# in bash, install ocrmypdf using %
# % is called 'magic' and lets you install via bash in a jupyter notebook
# %pip install ocrmypdf
# Out:
# Requirement already satisfied: ocrmypdf in /opt/anaconda3/lib/python3.13/site-packages (16.12.0)
# Requirement already satisfied: deprecation>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (2.1.0)
# Requirement already satisfied: img2pdf>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (0.6.3)
# Requirement already satisfied: packaging>=20 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (25.0)
# Requirement already satisfied: pdfminer-six>=20220319 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (20251107)
# Requirement already satisfied: pi-heif in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (1.1.1)
# Requirement already satisfied: pikepdf>=10 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (10.0.2)
# Requirement already satisfied: pillow>=10.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (12.0.0)
# Requirement already satisfied: pluggy>=1 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (1.5.0)
# Requirement already satisfied: rich>=13 in /opt/anaconda3/lib/python3.13/site-packages (from ocrmypdf) (14.2.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pdfminer-six>=20220319->ocrmypdf) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pdfminer-six>=20220319->ocrmypdf) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.23)
# Requirement already satisfied: Deprecated in /opt/anaconda3/lib/python3.13/site-packages (from pikepdf>=10->ocrmypdf) (1.3.1)
# Requirement already satisfied: lxml>=4.8 in /opt/anaconda3/lib/python3.13/site-packages (from pikepdf>=10->ocrmypdf) (5.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13->ocrmypdf) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13->ocrmypdf) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13->ocrmypdf) (0.1.2)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/anaconda3/lib/python3.13/site-packages (from Deprecated->pikepdf>=10->ocrmypdf) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# If prior cell runs correctly, you will be prompted to restart the kernel. Go ahead and do so.

# %%
#Bash
# Run this code to make sure ocrmypdf has installed
# !ocrmypdf --version
# Out:
# 16.12.0

# %%
import os
os.environ["PATH"] = "/opt/homebrew/bin:" + os.environ["PATH"]

# %%
# !which unpaper
# !unpaper --version
# Out:
# /opt/homebrew/bin/unpaper
# 7.0.0

# %%
import os
os.environ["PATH"] = "/opt/homebrew/bin:/usr/local/bin:" + os.environ["PATH"]

# %%
# !which gs
# !gs --version
# Out:
# /opt/homebrew/bin/gs
# 10.06.0

# %%
# bash command line to OCR one PDF
# %cd /Users/mhaigh/Downloads/iiif-studentactivism/manifest/
# !pwd
# !ocrmypdf --language eng --deskew --clean 'manifest.pdf' 'manifest.pdf'
# Out:
# /Users/mhaigh/Downloads/iiif-studentactivism/manifest
# /Users/mhaigh/Downloads/iiif-studentactivism/manifest
# Scanning contents     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 29/29 0:00:00
# Start processing 10 pages concurrently                                 ]8;id=69870;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipelines/ocr.py\ocr.py]8;;\:]8;id=764265;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipelines/ocr.py#96\96]8;;\
#     3 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=316371;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=925492;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#     5 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=928188;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=198770;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#     4 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=1536;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=116315;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#    19 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=879397;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=653208;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#    12 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=835643;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=914898;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#    17 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=75294;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=3935;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#    28 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=187423;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=404779;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#    29 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=345659;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=538195;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
#    29 [tesseract] Image too small to scale!! (2x36 vs min width ]8;id=318060;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=554088;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#269\269]8;;\
# of 3)
#    29 [tesseract] Line cannot be recognized!!                   ]8;id=522501;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=404175;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#269\269]8;;\
#    29 [tesseract] Image too small to scale!! (2x36 vs min width ]8;id=662723;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=120339;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#269\269]8;;\
# of 3)
#    29 [tesseract] Line cannot be recognized!!                   ]8;id=435481;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=184509;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#269\269]8;;\
#    24 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=575463;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=577276;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_exec/tesseract.py#251\251]8;;\
# OCR                   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 29/29 0:00:00% 28/29 0:00:04
# Postprocessing...                                                     ]8;id=930956;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipelines/ocr.py\ocr.py]8;;\:]8;id=682717;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipelines/ocr.py#144\144]8;;\
# PDF/A conversion      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 29/29 0:00:0027/29 0:00:01:01
# Linearizing           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 100/100 0:00:00m
# Recompressing JPEGs   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 29/29 0:00:00% 28/29 0:00:01
# Deflating JPEGs       ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 29/29 0:00:00% 28/29 0:00:01
# JBIG2                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:---:--
# Image optimization ratio: 1.02 savings: 1.8%                   ]8;id=664137;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=468479;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipeline.py#1002\1002]8;;\
# Total file size ratio: 1.02 savings: 2.0%                      ]8;id=130286;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=583169;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipeline.py#1005\1005]8;;\
# Output file is a PDF/A-2b (as expected)                           ]8;id=492107;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipelines/_common.py\_common.py]8;;\:]8;id=365406;file:///opt/anaconda3/lib/python3.13/site-packages/ocrmypdf/_pipelines/_common.py#474\474]8;;\

# %%
#the best way to test the OCR worked is to manually open the PDF and use control+f to see if you can search for words.

# %% [markdown]
# ## Step 4: Convert PDFs to .txt files: Bash
# This section is based on the Programming Historian tutorial: https://programminghistorian.org/en/lessons/working-with-batches-of-pdf-files
#
# Optional final step: use ChatGPT to clean up the outputs (see https://aigenealogyinsights.com/2023/03/22/ai-genealogy-use-case-cleaning-up-ocr-text/)

# %%
# !pip install pdftotext
# Out:
# Requirement already satisfied: pdftotext in /opt/anaconda3/lib/python3.13/site-packages (3.0.0)

# %%
# %cd /Users/mhaigh/Downloads/iiif-studentactivism/manifest/
# !pwd
# !pdftotext 'manifest.pdf' 'manifest.txt'
# Out:
# /Users/mhaigh/Downloads/iiif-studentactivism/manifest
# /Users/mhaigh/Downloads/iiif-studentactivism/manifest

# %%
#check that it worked by listing the files in the directory
# new .txt file means it was created
# !ls
# Out:
# image_1.jpg  image_15.jpg image_20.jpg image_26.jpg image_5.jpg  manifest.txt
# image_10.jpg image_16.jpg image_21.jpg image_27.jpg image_6.jpg
# image_11.jpg image_17.jpg image_22.jpg image_28.jpg image_7.jpg
# image_12.jpg image_18.jpg image_23.jpg image_29.jpg image_8.jpg
# image_13.jpg image_19.jpg image_24.jpg image_3.jpg  image_9.jpg
# image_14.jpg image_2.jpg  image_25.jpg image_4.jpg  manifest.pdf

# %% [markdown]
# ##
